# %%
import requests
from bs4 import BeautifulSoup
import os
import re

import nlp_project_functions as functions

import logging

logfile = "./logs/preprocessing.log"
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

file_handler = logging.FileHandler(logfile)
file_handler.setFormatter(formatter)
file_handler.setLevel(logging.INFO)

stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)
stream_handler.setLevel(logging.INFO)

logger = logging.getLogger("preprocessing.log")
logger.setLevel(logging.INFO)

logger.addHandler(file_handler)
logger.addHandler(stream_handler)

# %%
generic_names = ["König", "Königs", "Pfarrkirche", 
                 "Kirche", "Kirchen", "Kirch", 
                 "Land", "Mantua", "Dom",
                 "Tempel", "Stifter", "Stadtkirche",
                 "Stifters"]

# %%
for i in range(1,112):
    nr = str(i).rjust(4, '0')
    logger.info(f"Processing orgelpredigt_text E00{nr}")
    
    # fetch web page content and parse into beautiful soup object
    url = f"https://orgelpredigt.ur.de/E00{nr}txt"
    orgel_response = requests.get(url)
    orgel_soup = BeautifulSoup(orgel_response.text, 'html.parser')
    
    text = orgel_soup.find("div", {"class": "edition"})
    
    # initial clean up
    for tooltip in text.findAll("span", {"class": "tip"}):
        tooltip.decompose()
    for note in text.findAll("span", {"class": "note"}):
        note.decompose()
    for icon in text.findAll("a", {"class": "icon"}):
        icon.decompose()
    for pagebreak in text.findAll("span", {"class": "pagebreak"}):
        pagebreak.replace_with(" ")
    for supplied in text.findAll("span", {"class": "supplied"}):
        supplied.decompose()

    # filter out orgelpredigt_texts that are not edited
    if len(text.find_all("div", {'class': 'titel'})) == 0 and len(text.find_all("h3")) == 0:
        logger.info(f"Skipping orgelpredigt_text E00{nr}")
        continue
    else:
        # 1. Get list of normalised names
        names_list = text.find_all("div", {"class": "inhalt"})
        
        # skip orgelpredigt_texts that lack semantic markup
        if len(names_list[1].contents) < 6:
            logger.info("No semantic markup")
            continue
        
        # work around for some specific lists of entities
        if "Orgelpredigten" in names_list[1].contents[5].contents[7].text:
            names_list = names_list[1].contents[7].contents[9].contents[1]
        else:
            names_list = names_list[1].contents[5].contents[9].contents[1]
        
        if len(names_list) == 0:
            logger.warning("Names list is weirdly empty")

        # remove entity lists
        for x in text.findAll(["ol", "ul", "h2", "sup"]):
            x.decompose()
        for div in text.findAll("div", {"class": "inhalt"}):
            div.decompose()
        for div in text.findAll("div", {"class": "overlay"}):
            div.decompose()
        for div in text.findAll("div", {"class": "zitierlink"}):
            div.decompose()

        # remove line breaks
        for br in text.select("br"):
            br.replace_with(" ")

        # throw out table cells that have no additional markup
        for x in text.findAll("td"):
            if not x.find("span"):
                x.string = " "
                x.unwrap()

        orgelpredigt_text = functions.extract_names(text)

        # make entities simpler
        orgelpredigt_text = re.sub(r'<a href=\"E01[^>]*>([^<]*)</a>', r"<PERSON>\1</PERSON>", orgelpredigt_text)
        orgelpredigt_text = re.sub(r'<a href=\"E03[^>]*>([^<]*)</a>', r"<LOCATION>\1</LOCATION>", orgelpredigt_text)

        # add names that have no markup
        orgelpredigt_text = re.sub(r'(Herr\s|Herrn\s)([A-Z][a-zäöüß]+\s[A-Z][a-zäöüß]+)(?![^<P]*</PERSON>)', r'\1<PERSON>\2</PERSON>', orgelpredigt_text)

        # add in missing entities markup
        names_list = functions.create_name_list(orgelpredigt_text)

        for name in names_list[0]:
            if name not in generic_names:
                orgelpredigt_text = re.sub(r'[^>]' + name + r'\s', f"<PERSON>{name}</PERSON>", orgelpredigt_text)

        for name in names_list[1]:
            if name not in generic_names:
                orgelpredigt_text = re.sub(r'[^>]' + name + r'\s', f"<LOCATION>{name}</LOCATION>", orgelpredigt_text)

        #orgelpredigt_text = functions.sermon_cleanup(orgelpredigt_text)

        # add spaces around tags
        orgelpredigt_text = re.sub(r'</(PERSON|LOCATION)>(\S)', r'</\1> \2', orgelpredigt_text)
        orgelpredigt_text = re.sub(r'(\S)<(PERSON|LOCATION)>', r'\1 <\2>', orgelpredigt_text)

        with open(f"data/data_preprocessed/E00{nr}_text.txt", 'w', encoding='utf8') as f:
            f.write(orgelpredigt_text)
            logger.info(f"Saved text for orgelpredigt_text E00{nr}")
# Out:
# 2024-03-07 18:51:44,765 - preprocessing.log - INFO - Processing orgelpredigt_text E000001
# 2024-03-07 18:51:45,252 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000001
# 2024-03-07 18:51:45,252 - preprocessing.log - INFO - Processing orgelpredigt_text E000002
# 2024-03-07 18:51:45,744 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000002
# 2024-03-07 18:51:45,744 - preprocessing.log - INFO - Processing orgelpredigt_text E000003
# 2024-03-07 18:51:46,536 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000003
# 2024-03-07 18:51:46,537 - preprocessing.log - INFO - Processing orgelpredigt_text E000004
# 2024-03-07 18:51:46,654 - preprocessing.log - INFO - Skipping orgelpredigt_text E000004
# 2024-03-07 18:51:46,654 - preprocessing.log - INFO - Processing orgelpredigt_text E000005
# 2024-03-07 18:51:46,776 - preprocessing.log - INFO - Skipping orgelpredigt_text E000005
# 2024-03-07 18:51:46,777 - preprocessing.log - INFO - Processing orgelpredigt_text E000006
# 2024-03-07 18:51:47,023 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000006
# 2024-03-07 18:51:47,023 - preprocessing.log - INFO - Processing orgelpredigt_text E000007
# 2024-03-07 18:51:47,282 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000007
# 2024-03-07 18:51:47,283 - preprocessing.log - INFO - Processing orgelpredigt_text E000008
# 2024-03-07 18:51:47,455 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000008
# 2024-03-07 18:51:47,456 - preprocessing.log - INFO - Processing orgelpredigt_text E000009
# 2024-03-07 18:51:47,644 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000009
# 2024-03-07 18:51:47,644 - preprocessing.log - INFO - Processing orgelpredigt_text E000010
# 2024-03-07 18:51:47,765 - preprocessing.log - INFO - Skipping orgelpredigt_text E000010
# 2024-03-07 18:51:47,766 - preprocessing.log - INFO - Processing orgelpredigt_text E000011
# 2024-03-07 18:51:47,886 - preprocessing.log - INFO - Skipping orgelpredigt_text E000011
# 2024-03-07 18:51:47,886 - preprocessing.log - INFO - Processing orgelpredigt_text E000012
# 2024-03-07 18:51:48,013 - preprocessing.log - INFO - Skipping orgelpredigt_text E000012
# 2024-03-07 18:51:48,014 - preprocessing.log - INFO - Processing orgelpredigt_text E000013
# 2024-03-07 18:51:48,133 - preprocessing.log - INFO - Skipping orgelpredigt_text E000013
# 2024-03-07 18:51:48,133 - preprocessing.log - INFO - Processing orgelpredigt_text E000014
# 2024-03-07 18:51:48,329 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000014
# 2024-03-07 18:51:48,330 - preprocessing.log - INFO - Processing orgelpredigt_text E000015
# 2024-03-07 18:51:48,608 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000015
# 2024-03-07 18:51:48,608 - preprocessing.log - INFO - Processing orgelpredigt_text E000016
# 2024-03-07 18:51:48,839 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000016
# 2024-03-07 18:51:48,840 - preprocessing.log - INFO - Processing orgelpredigt_text E000017
# 2024-03-07 18:51:49,047 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000017
# 2024-03-07 18:51:49,048 - preprocessing.log - INFO - Processing orgelpredigt_text E000018
# 2024-03-07 18:51:49,158 - preprocessing.log - INFO - Skipping orgelpredigt_text E000018
# 2024-03-07 18:51:49,159 - preprocessing.log - INFO - Processing orgelpredigt_text E000019
# 2024-03-07 18:51:49,273 - preprocessing.log - INFO - Skipping orgelpredigt_text E000019
# 2024-03-07 18:51:49,274 - preprocessing.log - INFO - Processing orgelpredigt_text E000020
# 2024-03-07 18:51:49,463 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000020
# 2024-03-07 18:51:49,463 - preprocessing.log - INFO - Processing orgelpredigt_text E000021
# 2024-03-07 18:51:49,739 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000021
# 2024-03-07 18:51:49,740 - preprocessing.log - INFO - Processing orgelpredigt_text E000022
# 2024-03-07 18:51:49,853 - preprocessing.log - INFO - Skipping orgelpredigt_text E000022
# 2024-03-07 18:51:49,854 - preprocessing.log - INFO - Processing orgelpredigt_text E000023
# 2024-03-07 18:51:50,111 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000023
# 2024-03-07 18:51:50,112 - preprocessing.log - INFO - Processing orgelpredigt_text E000024
# 2024-03-07 18:51:50,543 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000024
# 2024-03-07 18:51:50,543 - preprocessing.log - INFO - Processing orgelpredigt_text E000025
# 2024-03-07 18:51:50,650 - preprocessing.log - INFO - Skipping orgelpredigt_text E000025
# 2024-03-07 18:51:50,652 - preprocessing.log - INFO - Processing orgelpredigt_text E000026
# 2024-03-07 18:51:50,756 - preprocessing.log - INFO - Skipping orgelpredigt_text E000026
# 2024-03-07 18:51:50,756 - preprocessing.log - INFO - Processing orgelpredigt_text E000027
# 2024-03-07 18:51:51,453 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000027
# 2024-03-07 18:51:51,454 - preprocessing.log - INFO - Processing orgelpredigt_text E000028
# 2024-03-07 18:51:51,570 - preprocessing.log - INFO - Skipping orgelpredigt_text E000028
# 2024-03-07 18:51:51,570 - preprocessing.log - INFO - Processing orgelpredigt_text E000029
# 2024-03-07 18:51:52,178 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000029
# 2024-03-07 18:51:52,178 - preprocessing.log - INFO - Processing orgelpredigt_text E000030
# 2024-03-07 18:51:52,584 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000030
# 2024-03-07 18:51:52,584 - preprocessing.log - INFO - Processing orgelpredigt_text E000031
# 2024-03-07 18:51:52,781 - preprocessing.log - INFO - No semantic markup
# 2024-03-07 18:51:52,781 - preprocessing.log - INFO - Processing orgelpredigt_text E000032
# 2024-03-07 18:51:52,903 - preprocessing.log - INFO - Skipping orgelpredigt_text E000032
# 2024-03-07 18:51:52,904 - preprocessing.log - INFO - Processing orgelpredigt_text E000033
# 2024-03-07 18:51:53,011 - preprocessing.log - INFO - Skipping orgelpredigt_text E000033
# 2024-03-07 18:51:53,011 - preprocessing.log - INFO - Processing orgelpredigt_text E000034
# 2024-03-07 18:51:53,262 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000034
# 2024-03-07 18:51:53,263 - preprocessing.log - INFO - Processing orgelpredigt_text E000035
# 2024-03-07 18:51:53,498 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000035
# 2024-03-07 18:51:53,499 - preprocessing.log - INFO - Processing orgelpredigt_text E000036
# 2024-03-07 18:51:54,388 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000036
# 2024-03-07 18:51:54,390 - preprocessing.log - INFO - Processing orgelpredigt_text E000037
# 2024-03-07 18:51:54,623 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000037
# 2024-03-07 18:51:54,623 - preprocessing.log - INFO - Processing orgelpredigt_text E000038
# 2024-03-07 18:51:55,031 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000038
# 2024-03-07 18:51:55,032 - preprocessing.log - INFO - Processing orgelpredigt_text E000039
# 2024-03-07 18:51:55,395 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000039
# 2024-03-07 18:51:55,396 - preprocessing.log - INFO - Processing orgelpredigt_text E000040
# 2024-03-07 18:51:55,524 - preprocessing.log - INFO - Skipping orgelpredigt_text E000040
# 2024-03-07 18:51:55,524 - preprocessing.log - INFO - Processing orgelpredigt_text E000041
# 2024-03-07 18:51:55,979 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000041
# 2024-03-07 18:51:55,980 - preprocessing.log - INFO - Processing orgelpredigt_text E000042
# 2024-03-07 18:51:56,530 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000042
# 2024-03-07 18:51:56,796 - preprocessing.log - INFO - Processing orgelpredigt_text E000043
# 2024-03-07 18:51:56,918 - preprocessing.log - INFO - Skipping orgelpredigt_text E000043
# 2024-03-07 18:51:56,919 - preprocessing.log - INFO - Processing orgelpredigt_text E000044
# 2024-03-07 18:51:57,030 - preprocessing.log - INFO - Skipping orgelpredigt_text E000044
# 2024-03-07 18:51:57,031 - preprocessing.log - INFO - Processing orgelpredigt_text E000045
# 2024-03-07 18:51:58,659 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000045
# 2024-03-07 18:51:58,660 - preprocessing.log - INFO - Processing orgelpredigt_text E000046
# 2024-03-07 18:51:59,219 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000046
# 2024-03-07 18:51:59,220 - preprocessing.log - INFO - Processing orgelpredigt_text E000047
# 2024-03-07 18:51:59,332 - preprocessing.log - INFO - Skipping orgelpredigt_text E000047
# 2024-03-07 18:51:59,333 - preprocessing.log - INFO - Processing orgelpredigt_text E000048
# 2024-03-07 18:51:59,640 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000048
# 2024-03-07 18:51:59,641 - preprocessing.log - INFO - Processing orgelpredigt_text E000049
# 2024-03-07 18:51:59,747 - preprocessing.log - INFO - Skipping orgelpredigt_text E000049
# 2024-03-07 18:51:59,747 - preprocessing.log - INFO - Processing orgelpredigt_text E000050
# 2024-03-07 18:51:59,855 - preprocessing.log - INFO - Skipping orgelpredigt_text E000050
# 2024-03-07 18:51:59,856 - preprocessing.log - INFO - Processing orgelpredigt_text E000051
# 2024-03-07 18:52:00,311 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000051
# 2024-03-07 18:52:00,311 - preprocessing.log - INFO - Processing orgelpredigt_text E000052
# 2024-03-07 18:52:00,845 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000052
# 2024-03-07 18:52:00,845 - preprocessing.log - INFO - Processing orgelpredigt_text E000053
# 2024-03-07 18:52:02,391 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000053
# 2024-03-07 18:52:02,392 - preprocessing.log - INFO - Processing orgelpredigt_text E000054
# 2024-03-07 18:52:02,507 - preprocessing.log - INFO - Skipping orgelpredigt_text E000054
# 2024-03-07 18:52:02,507 - preprocessing.log - INFO - Processing orgelpredigt_text E000055
# 2024-03-07 18:52:03,624 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000055
# 2024-03-07 18:52:03,625 - preprocessing.log - INFO - Processing orgelpredigt_text E000056
# 2024-03-07 18:52:04,002 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000056
# 2024-03-07 18:52:04,003 - preprocessing.log - INFO - Processing orgelpredigt_text E000057
# 2024-03-07 18:52:04,477 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000057
# 2024-03-07 18:52:04,478 - preprocessing.log - INFO - Processing orgelpredigt_text E000058
# 2024-03-07 18:52:05,026 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000058
# 2024-03-07 18:52:05,027 - preprocessing.log - INFO - Processing orgelpredigt_text E000059
# 2024-03-07 18:52:05,815 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000059
# 2024-03-07 18:52:05,815 - preprocessing.log - INFO - Processing orgelpredigt_text E000060
# 2024-03-07 18:52:06,182 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000060
# 2024-03-07 18:52:06,183 - preprocessing.log - INFO - Processing orgelpredigt_text E000061
# 2024-03-07 18:52:06,969 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000061
# 2024-03-07 18:52:06,970 - preprocessing.log - INFO - Processing orgelpredigt_text E000062
# 2024-03-07 18:52:07,082 - preprocessing.log - INFO - Skipping orgelpredigt_text E000062
# 2024-03-07 18:52:07,083 - preprocessing.log - INFO - Processing orgelpredigt_text E000063
# 2024-03-07 18:52:07,410 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000063
# 2024-03-07 18:52:07,460 - preprocessing.log - INFO - Processing orgelpredigt_text E000064
# 2024-03-07 18:52:07,561 - preprocessing.log - INFO - Skipping orgelpredigt_text E000064
# 2024-03-07 18:52:07,584 - preprocessing.log - INFO - Processing orgelpredigt_text E000065
# 2024-03-07 18:52:08,272 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000065
# 2024-03-07 18:52:08,278 - preprocessing.log - INFO - Processing orgelpredigt_text E000066
# 2024-03-07 18:52:08,387 - preprocessing.log - INFO - Skipping orgelpredigt_text E000066
# 2024-03-07 18:52:08,388 - preprocessing.log - INFO - Processing orgelpredigt_text E000067
# 2024-03-07 18:52:09,211 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000067
# 2024-03-07 18:52:09,212 - preprocessing.log - INFO - Processing orgelpredigt_text E000068
# 2024-03-07 18:52:10,278 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000068
# 2024-03-07 18:52:10,278 - preprocessing.log - INFO - Processing orgelpredigt_text E000069
# 2024-03-07 18:52:11,337 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000069
# 2024-03-07 18:52:11,339 - preprocessing.log - INFO - Processing orgelpredigt_text E000070
# 2024-03-07 18:52:11,891 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000070
# 2024-03-07 18:52:11,891 - preprocessing.log - INFO - Processing orgelpredigt_text E000071
# 2024-03-07 18:52:12,002 - preprocessing.log - INFO - Skipping orgelpredigt_text E000071
# 2024-03-07 18:52:12,003 - preprocessing.log - INFO - Processing orgelpredigt_text E000072
# 2024-03-07 18:52:12,681 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000072
# 2024-03-07 18:52:12,682 - preprocessing.log - INFO - Processing orgelpredigt_text E000073
# 2024-03-07 18:52:13,391 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000073
# 2024-03-07 18:52:13,392 - preprocessing.log - INFO - Processing orgelpredigt_text E000074
# 2024-03-07 18:52:13,711 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000074
# 2024-03-07 18:52:13,712 - preprocessing.log - INFO - Processing orgelpredigt_text E000075
# 2024-03-07 18:52:14,177 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000075
# 2024-03-07 18:52:14,178 - preprocessing.log - INFO - Processing orgelpredigt_text E000076
# 2024-03-07 18:52:14,297 - preprocessing.log - INFO - Skipping orgelpredigt_text E000076
# 2024-03-07 18:52:14,297 - preprocessing.log - INFO - Processing orgelpredigt_text E000077
# 2024-03-07 18:52:14,414 - preprocessing.log - INFO - Skipping orgelpredigt_text E000077
# 2024-03-07 18:52:14,415 - preprocessing.log - INFO - Processing orgelpredigt_text E000078
# 2024-03-07 18:52:14,930 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000078
# 2024-03-07 18:52:15,334 - preprocessing.log - INFO - Processing orgelpredigt_text E000079
# 2024-03-07 18:52:15,935 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000079
# 2024-03-07 18:52:15,935 - preprocessing.log - INFO - Processing orgelpredigt_text E000080
# 2024-03-07 18:52:16,040 - preprocessing.log - INFO - Skipping orgelpredigt_text E000080
# 2024-03-07 18:52:16,040 - preprocessing.log - INFO - Processing orgelpredigt_text E000081
# 2024-03-07 18:52:16,164 - preprocessing.log - INFO - Skipping orgelpredigt_text E000081
# 2024-03-07 18:52:16,165 - preprocessing.log - INFO - Processing orgelpredigt_text E000082
# 2024-03-07 18:52:16,589 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000082
# 2024-03-07 18:52:16,589 - preprocessing.log - INFO - Processing orgelpredigt_text E000083
# 2024-03-07 18:52:17,068 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000083
# 2024-03-07 18:52:17,069 - preprocessing.log - INFO - Processing orgelpredigt_text E000084
# 2024-03-07 18:52:17,181 - preprocessing.log - INFO - Skipping orgelpredigt_text E000084
# 2024-03-07 18:52:17,181 - preprocessing.log - INFO - Processing orgelpredigt_text E000085
# 2024-03-07 18:52:17,586 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000085
# 2024-03-07 18:52:17,587 - preprocessing.log - INFO - Processing orgelpredigt_text E000086
# 2024-03-07 18:52:18,102 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000086
# 2024-03-07 18:52:18,103 - preprocessing.log - INFO - Processing orgelpredigt_text E000087
# 2024-03-07 18:52:18,225 - preprocessing.log - INFO - Skipping orgelpredigt_text E000087
# 2024-03-07 18:52:18,225 - preprocessing.log - INFO - Processing orgelpredigt_text E000088
# 2024-03-07 18:52:18,346 - preprocessing.log - INFO - Skipping orgelpredigt_text E000088
# 2024-03-07 18:52:18,347 - preprocessing.log - INFO - Processing orgelpredigt_text E000089
# 2024-03-07 18:52:18,770 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000089
# 2024-03-07 18:52:18,771 - preprocessing.log - INFO - Processing orgelpredigt_text E000090
# 2024-03-07 18:52:19,236 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000090
# 2024-03-07 18:52:19,237 - preprocessing.log - INFO - Processing orgelpredigt_text E000091
# 2024-03-07 18:52:19,688 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000091
# 2024-03-07 18:52:19,689 - preprocessing.log - INFO - Processing orgelpredigt_text E000092
# 2024-03-07 18:52:20,731 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000092
# 2024-03-07 18:52:20,732 - preprocessing.log - INFO - Processing orgelpredigt_text E000093
# 2024-03-07 18:52:20,840 - preprocessing.log - INFO - Skipping orgelpredigt_text E000093
# 2024-03-07 18:52:20,841 - preprocessing.log - INFO - Processing orgelpredigt_text E000094
# 2024-03-07 18:52:20,947 - preprocessing.log - INFO - Skipping orgelpredigt_text E000094
# 2024-03-07 18:52:20,947 - preprocessing.log - INFO - Processing orgelpredigt_text E000095
# 2024-03-07 18:52:21,704 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000095
# 2024-03-07 18:52:21,705 - preprocessing.log - INFO - Processing orgelpredigt_text E000096
# 2024-03-07 18:52:22,480 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000096
# 2024-03-07 18:52:22,481 - preprocessing.log - INFO - Processing orgelpredigt_text E000097
# 2024-03-07 18:52:22,587 - preprocessing.log - INFO - Skipping orgelpredigt_text E000097
# 2024-03-07 18:52:22,588 - preprocessing.log - INFO - Processing orgelpredigt_text E000098
# 2024-03-07 18:52:23,223 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000098
# 2024-03-07 18:52:23,224 - preprocessing.log - INFO - Processing orgelpredigt_text E000099
# 2024-03-07 18:52:23,943 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000099
# 2024-03-07 18:52:23,943 - preprocessing.log - INFO - Processing orgelpredigt_text E000100
# 2024-03-07 18:52:24,061 - preprocessing.log - INFO - Skipping orgelpredigt_text E000100
# 2024-03-07 18:52:24,062 - preprocessing.log - INFO - Processing orgelpredigt_text E000101
# 2024-03-07 18:52:24,184 - preprocessing.log - INFO - Skipping orgelpredigt_text E000101
# 2024-03-07 18:52:24,184 - preprocessing.log - INFO - Processing orgelpredigt_text E000102
# 2024-03-07 18:52:24,300 - preprocessing.log - INFO - Skipping orgelpredigt_text E000102
# 2024-03-07 18:52:24,301 - preprocessing.log - INFO - Processing orgelpredigt_text E000103
# 2024-03-07 18:52:24,416 - preprocessing.log - INFO - Skipping orgelpredigt_text E000103
# 2024-03-07 18:52:24,416 - preprocessing.log - INFO - Processing orgelpredigt_text E000104
# 2024-03-07 18:52:24,703 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000104
# 2024-03-07 18:52:24,703 - preprocessing.log - INFO - Processing orgelpredigt_text E000105
# 2024-03-07 18:52:24,817 - preprocessing.log - INFO - Skipping orgelpredigt_text E000105
# 2024-03-07 18:52:24,817 - preprocessing.log - INFO - Processing orgelpredigt_text E000106
# 2024-03-07 18:52:25,300 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000106
# 2024-03-07 18:52:25,301 - preprocessing.log - INFO - Processing orgelpredigt_text E000107
# 2024-03-07 18:52:25,416 - preprocessing.log - INFO - Skipping orgelpredigt_text E000107
# 2024-03-07 18:52:25,417 - preprocessing.log - INFO - Processing orgelpredigt_text E000108
# 2024-03-07 18:52:25,722 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000108
# 2024-03-07 18:52:25,723 - preprocessing.log - INFO - Processing orgelpredigt_text E000109
# 2024-03-07 18:52:26,092 - preprocessing.log - INFO - Saved text for orgelpredigt_text E000109
# 2024-03-07 18:52:26,093 - preprocessing.log - INFO - Processing orgelpredigt_text E000110
# 2024-03-07 18:52:26,201 - preprocessing.log - INFO - Skipping orgelpredigt_text E000110
# 2024-03-07 18:52:26,202 - preprocessing.log - INFO - Processing orgelpredigt_text E000111
# 2024-03-07 18:52:26,327 - preprocessing.log - INFO - Skipping orgelpredigt_text E000111

# %%
for file in os.listdir('data/abacus_download'):
    if file.endswith("xml"):
        logger.inf0(f"Processing {file}")
        
        with open(f"data/abacus_download/{file}") as f:
            text = f.read()
        
        aba_soup = BeautifulSoup(text, 'xml')

        #get content tags
        dedication = aba_soup.find("div", {"type": "dedication"})
        body = aba_soup.find("body")
        back = aba_soup.find("back")

        aba_soup.body.wrap(aba_soup.new_tag("wrapper"))

        if not dedication == None:
            body.insert_before(dedication)
        if not back == None:
            body.insert_after(back)

        wrapper = aba_soup.find("wrapper")

        # remove page numbers, ornaments and catches
        for item in wrapper.findAll("fw", {"type": "header"}):
            item.decompose()
        for item in wrapper.findAll("fw", {"type": "catch"}):
            item.decompose()
        for item in wrapper.findAll("seg", {"type": "ornament"}):
            item.decompose()

        aba_text = functions.extract_names_aba(wrapper)
        aba_text = re.sub(r'\s+', ' ', aba_text)

        # make entities simpler
        aba_text = re.sub(r'<persName (.*?)>\s*(.*?)\s*<\/persName>', r"<PERSON>\2</PERSON>", aba_text)
        aba_text = re.sub(r'<placeName (.*?)>\s*(.*?)\s*<\/placeName>', r"<LOCATION>\2</LOCATION>", aba_text)

        # remove / and whitespace around punctuation
        aba_text = re.sub(r' ([\.,;:!?])', r"\1", aba_text)
        aba_text = re.sub(r'(?<!<)/', '', aba_text)
        aba_text = aba_text.replace('<wrapper>', '').replace('</wrapper>', '')

        with open(f'data/data_preprocessed/{file[:-4]}.txt', 'w', encoding='utf8') as f:
            f.write(aba_text)
# Out:
# Processing Abraham-Loesch_Wienn.xml
# Processing Abraham-Mercks_Wien.xml
# Processing Abraham-Todten_Capelle.xml
# Processing Abraham-Augustini_feuriges_Hertz.xml
# Processing Abraham-Todten_Bruderschaft.xml
